# %% [markdown]
# ----------
# # Estructuras de Control
# ----------
# ## Instrucciones de elección
#
# ### IF statements
#
# La expresión `if...:` corre diferentes ramificaciones de código e incluso evalua a un valor diferente dependiendo de la expresión booleana otorgada.
#
# #### Sintaxis
#
# ```fsharp
# if (boolean-expression):
#     expression1
# ```

# %%
List = range(10)


x = 100

if ( x  == 100 ): 
    print "x = 100"

print "The if has ended!!!"
# Out:
# x = 100
# The if has ended!!!

# %% [markdown]
# ------------
# ### IF...ELSE... statement
#
# La expresión `if...: ..: else`  corre diferentes ramificaciones de código e incluso evalua a un valor diferente dependiendo de la expresión booleana otorgada.
#
# #### Sintaxis
#
# ```fsharp
# if (boolean-expression):
#     expression1
# else:
#     expression2
# ```
#
#
# ------------

# %%
List = [0,1,2,3,4,5]

n = 0

if (List[n]==1):
    print "first element in the list is 1"
else:
    print "first element in the list is 0"
    n+=1
    if (List[n]==2):
        print "first element in the list is 2"
    else:
        print "first element in the list is 1"
        n+=1
        if (List[n]==3):
            print "first element in the list is 3"
        else:
            print "first element in the list is 2"
            n+=1

print "The last element to be examined ", List[n-1]
# Out:
# first element in the list is 0
# first element in the list is 1
# first element in the list is 2
# The last element to be examined  2

# %% [markdown]
# ------------
# ### IF...ELIF...ELSE statement
#
# #### Sintaxis
#
# ```fsharp
# if (boolean-expression):
#     expression1
# elif:
#     expression2
# else:
#     expression3
# ```
#
# ------------

# %%
List = [0,1,2,3,4,5]

n = 0

if (List[n]==0):
    print "first element in the list is 0"
    n+=1
elif (List[n]==-1):
    print "first element in the list is -1"
    n+=1
elif (List[n]==2):
    print "first element in the list is 2"
    n+=1
else: 
    print "List is ", List
# Out:
# first element in the list is 0

# %% [markdown]
# --------
# ## Instrucciones de Ciclos
# --------
# ### Ciclo While
#
# #### Sintaxis
#
# ```fsharp
# while (boolean-expression):
#     expression1
#     expression2
#     ...
# ```
# -------

# %%
# A Classic One
count = 0
while (count<9):
    print "Count: ",count
    count+=1
print "Out of while loop"
# Out:
# Count:  0
# Count:  1
# Count:  2
# Count:  3
# Count:  4
# Count:  5
# Count:  6
# Count:  7
# Count:  8
# Out of while loop

# %% [markdown]
# -----------
# ### else statements in while loops
#
#     Aquí basicamentes haces el cuerpo del ciclo o el cuerpo del else
# -----------

# %%
count = 64

while count > 2**2:
    count = count>>1
    print "Count inside the loop: ",count
else:
    print "Outside of the loop"
# Out:
# Count inside the loop:  32
# Count inside the loop:  16
# Count inside the loop:  8
# Count inside the loop:  4
# Outside of the loop

# %%
count = 64

while True:
    if count == 2**2:
        break
    count = count>>1
    print "Count inside the loop: ",count

print "Count outside the loop: ", count
# Out:
# Count inside the loop:  32
# Count inside the loop:  16
# Count inside the loop:  8
# Count inside the loop:  4
# Count outside the loop:  4

# %% [markdown]
# -----------
# ### ciclos for
#
# #### Syntaxis
# ```fsharp
# for i in a list of elements:
#     expression1
#     expression2
#     ...
# ```
#
# -----------

# %%
for letter in 'DataLab':     # First Example
   print 'Current Letter :', letter

fruits = ['banana', 'apple',  'mango']
for fruit in fruits:        # Second Example
   print 'Current fruit :', fruit


print "We Finish it"
# Out:
# Current Letter : D
# Current Letter : a
# Current Letter : t
# Current Letter : a
# Current Letter : L
# Current Letter : a
# Current Letter : b
# Current fruit : banana
# Current fruit : apple
# Current fruit : mango
# Current index:  0
# Current index:  1
# Current index:  2
# Current index:  3
# Current index:  4
# Current index:  5
# We Finish it

# %%
for x in range(10): # The Range creates a list 
    if x>5:
        break
    print "Current index: ", x
# Out:
# Current index:  0
# Current index:  1
# Current index:  2
# Current index:  3
# Current index:  4
# Current index:  5

# %%
for x in range(10):
    if x%2 == 0:
        pass
        pass
        pass
        continue
    print "Current odd index: ", x
# Out:
# Current odd index:  1
# Current odd index:  3
# Current odd index:  5
# Current odd index:  7
# Current odd index:  9
